# %% [markdown]
# # Preprocessing and Feature Selection

# %%
from enum import IntEnum
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter
from pathlib import Path
import sys

# %%
project_root = Path().absolute().parent
sys.path.insert(0, str(project_root))

from config import Config

data_path = Config.FARS_CLEANED_DIR / "fars.csv"
df = pd.read_csv(data_path)
df.head()
# Out:
#    ST_CASE STATENAME  PERSONS     ROUTENAME     FUNC_SYSNAME RUR_URBNAME  \
# 0    10001   Alabama        1  U.S. Highway  Major Collector       Rural
# 1    10002   Alabama        1        County            Local       Rural
# 2    10003   Alabama        1        County  Major Collector       Rural
# 3    10004   Alabama        3        County            Local       Rural
# 4    10005   Alabama        4    Interstate       Interstate       Rural
#
#    MONTH  DAY DAY_WEEKNAME  HOUR  ...          TYP_INTNAME  REL_ROADNAME  \
# 0      1    4    Wednesday  22.0  ...  Not an Intersection   On Roadside
# 1      3   20       Monday   2.0  ...  Not an Intersection   On Roadside
# 2      3   18     Saturday  22.0  ...  Not an Intersection   On Roadside
# 3      3   17       Friday  19.0  ...  Not an Intersection   On Roadside
# 4      3   17       Friday  14.0  ...  Not an Intersection   On Roadside
#
#   WRK_ZONE        LGT_CONDNAME WEATHERNAME SCH_BUSNAME     RAIL  TOTAL_HARM  \
# 0        0  Dark - Not Lighted       Clear          No  0000000         4.0
# 1        0  Dark - Not Lighted       Clear          No  0000000         4.0
# 2        0  Dark - Not Lighted       Clear          No  0000000         4.0
# 3        0  Dark - Not Lighted        Rain          No  0000000        10.0
# 4        0            Daylight        Rain          No  0000000        12.0
#
#   DRUNK_DRIVERS DRIVERS_ON_DRUGS
# 0           0.0              0.0
# 1           1.0              1.0
# 2           1.0              0.0
# 3           1.0              0.0
# 4           0.0              1.0
#
# [5 rows x 25 columns]

# %% [markdown]
# ### 1. Target Variable Definition
#
# Since the dataset currently includes DRUNK_DRIVERS and DRIVERS_ON_DRUGS and we want to predict if the driver was "in some way impaired", we have combine both features into a single binary class.

# %%
# Create the binary target: 1 if impaired, 0 otherwise
target = 'IMPAIRED'
df = df[target] = ((df['DRUNK_DRIVERS'] > 0) | (df['DRIVERS_ON_DRUGS'] > 0)).astype(int)
# df = df.drop(columns=['DRUNK_DRIVERS', 'DRIVERS_ON_DRUGS'])

# %% [markdown]
# ### 2. Feature Engineering and Further Data Cleaning
#
# We need to update/convert a few columns:
# - ST_CASE is not needed anymore.
# - RAIL identifies if the crash occurred in or near a rail grade crossing. It is either 0000000 (not applicable), xxxxxxA (federal code for rail grade crossing) or 9999999 (unknown). Thus we will convert this to a binary feature. Treat 0000000 (N/A) and 9999999 (Unknown) as 0, everything else (actual codes) as 1
# - Ensure severity metrics are numeric
# - Convert time to cyclical encoding (model needs to see "night cycle"). For example, 23.00 is far from 01.00, but the number 23 is far from 1

# %%
# Rail Crossing Binary Feature
df['IS_RAIL_CROSSING'] = np.where(
    df['RAIL'].astype(str).isin(['0000000', '9999999']), 
    0, 
    1
)

# Severity & On-Scene Metrics
severity_cols = ['FATALS', 'PERSONS', 'TOTAL_HARM']
for col in severity_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0)

# Cyclical Time Encoding
df['HOUR_SIN'] = np.sin(2 * np.pi * df['HOUR'] / 24)
df['HOUR_COS'] = np.cos(2 * np.pi * df['HOUR'] / 24)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 3
#       1 # Rail Crossing Binary Feature
#       2 df['IS_RAIL_CROSSING'] = np.where(
# ----> 3     df['RAIL'].astype(str).isin(['0000000', '9999999']),
#       4     0,
#       5     1
#       6 )
#       8 # Severity & On-Scene Metrics
#       9 severity_cols = ['FATALS', 'PERSONS', 'TOTAL_HARM']
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:1040, in Series.__getitem__(self, key)
#    1037     return self._values[key]
#    1039 elif key_is_scalar:
# -> 1040     return self._get_value(key)
#    1042 # Convert generator to list before going through hashable part
#    1043 # (We will iterate through the generator there to check for slices)
#    1044 if is_iterator(key):
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/series.py:1156, in Series._get_value(self, label, takeable)
#    1153     return self._values[label]
#    1155 # Similar to Index.get_value, but we do not fall back to positional
# -> 1156 loc = self.index.get_loc(label)
#    1158 if is_integer(loc):
#    1159     return self._values[loc]
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/pandas/core/indexes/range.py:418, in RangeIndex.get_loc(self, key)
#     416         raise KeyError(key) from err
#     417 if isinstance(key, Hashable):
# --> 418     raise KeyError(key)
#     419 self._check_indexing_error(key)
#     420 raise KeyError(key)
#
# KeyError: 'RAIL'
